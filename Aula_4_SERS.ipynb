# %% [markdown]
# <a href="https://colab.research.google.com/github/Kekeoliver/SERS-2SEM-CP2/blob/main/Aula_4_SERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##EXERCICIO
#
# Treinar um modelo preditivo de classificação binára. O modelo fará as previsões com base nos dados da coluna 'stabf' mostrando se a rede elétrica está INSTÁVEL ou ESTÁVEL. Utilizar o algoritimo Regressão Logística (Logistic regression do sklearn) para o treinamento do modelo. Avaliar o modelo com base na acurácia.
